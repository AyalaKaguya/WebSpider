# %% [markdown]
# # 笔趣阁自动化

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import os

# 抽象爬虫层, 用于识别各种笔趣阁
def gen_metadata():
    return {
        'title': '未知小说',
        'meta': '未找到元数据',
        '作者': '未知作者',
        'chapters': [],
    } # 以上元数据是必须的, chapter格式如下： ('相对路径', '章节标题') 其中章节标题会与网页标题相比较


class Get_2biqu:
    """www.2biqu.com"""
    @staticmethod
    def get_metadata(soup: BeautifulSoup):
        metadata = gen_metadata()

        for c in soup.find('div', class_='top').children:
            if c.text == '\n':
                continue
            if c.name == 'h1':
                metadata['title'] = c.text.strip()
            elif c.name == 'div':
                metadata['meta'] = c.text.strip()

        for c in soup.find('ul', id='section-list').children:
            section = c.text.strip()
            if section == '':
                continue
            if c.name == 'li':
                metadata['chapters'].append((c.a['href'], c.a.text.strip()))
                
        meta_list = metadata['meta'].split('\n')
        meta_list = [i.strip().split('：') for i in meta_list if i.strip() != '']
        for i in meta_list:
            if len(i) == 2:
                metadata[i[0]] = i[1]
            elif len(i) == 1:
                i = i[0].split(':')
                metadata[i[0]] = i[1]
            else:
                print(i)

        return metadata

    @staticmethod
    def get_title(soup: BeautifulSoup):
        return soup.find('h1').text.strip()

    @staticmethod
    def get_content(soup: BeautifulSoup):
        return soup.find('div', id='content').text.strip()
    
    @staticmethod
    def get_content_cut(content: str):
        return [i.strip() for i in content.split('\n') if i.strip() != '']

class Get_52bqg:
    """www.52bqg.com"""
    @staticmethod
    def get_metadata(soup: BeautifulSoup):
        metadata = gen_metadata()
        metadata['meta'] = ""
        for c in soup.find('div', id='info').children:
            if c.text == '\n':
                continue
            if c.name == 'h1':
                metadata['title'] = c.text.strip()
            elif c.name == 'p':
                metadata['meta'] += c.text.strip()+'\n'
                key,value = c.text.strip().split('：')
                metadata[key] = value

        intro = soup.find('div', id='intro').text.strip()
        metadata['meta'] += intro+'\n'

        section_tmp = []
        for c in soup.find_all('dd'):
            if c.text.strip() == '':
                continue
            section_tmp.append((c.a['href'], c.a.text.strip()))
            
        section_tmp = list(reversed(section_tmp))
        seen = set()
        section_tmp = [x for x in section_tmp if not (x in seen or seen.add(x))]
        metadata['chapters'].extend(list(reversed(section_tmp)))
            
        return metadata

    @staticmethod
    def get_title(soup: BeautifulSoup):
        return soup.find('h1').text.strip()

    @staticmethod
    def get_content(soup: BeautifulSoup):
        title = Get_52bqg.get_title(soup) + '\n'
        return title + soup.find('div', id='content').text.strip().replace('\xa0'*4, '\n')
    
    @staticmethod
    def get_content_cut(content: str):
        return [i.strip() for i in content.split('\n') if i.strip() != '']
    
def get_parser(url: str):
    if 'www.2biqu.com' in url:
        print('使用2biqu解析器')
        return Get_2biqu
    if 'www.52bqg.org' in url:
        print('使用52bqg解析器')
        return Get_52bqg
    else:
        raise Exception('未知网站')

# %% [markdown]
# 前往目标页面

# %%
options = webdriver.ChromeOptions()
options.add_argument("disable-blink-features=AutomationControlled")
browser = webdriver.Chrome(options=options)

# root_url = 'https://www.2biqu.com/biqu*****/'
root_url = 'https://www.52bqg.org/book_*****/'

parser = get_parser(root_url)
browser.get(root_url) # 如果有各种问题(如502)请刷新浏览器
# Out:
# 使用52bqg解析器

# %% [markdown]
# 打开一个文本文档用于存放书的内容

# %%
soup = BeautifulSoup(browser.page_source, 'html.parser')

metadata = parser.get_metadata(soup)
print("标题：《", metadata['title'], "》", sep='')
print(metadata['meta'])
print("总共有 {} 章节".format(len(metadata['chapters'])))

file_name = metadata['title'] + '.txt' if '作者' not in metadata else metadata['title'] + ' - ' + metadata['作者'] + '.txt'
if os.path.exists(file_name):
    print('文件已存在，将追加内容')
else:
    print('文件不存在，写入元数据')
    with open(file_name, 'w+', encoding='utf-8') as fp:
        fp.write(metadata['title'] + '\n\n')
        fp.write(metadata['meta'] + ' \n\n')
txtfp = open(file_name, 'a', encoding='utf-8')
# Out:
# 标题：《神印王座II皓月当空》
# 作者：唐家三少
# 动作：投票推荐， 加入书架， 直达底部
# 更新时间：2024-01-09 10:03 [共326万字]
# 最新：正文卷 第三百七十九章 凌梦露的底牌
# 《神印王座》第二部！   龙生两子亦有不同，天才的哥哥与废柴的弟弟，明明是长得一模一样的双胞胎，却有着天壤之别，唯有他们那想要躺平的心却是一模一样。在他们出生的那一晚，皓月当空。
#
# 总共有 377 章节
# 文件不存在，写入元数据

# %% [markdown]
# 爬取每一章的数据

# %%
# 爬虫参数
stop_worlds = ['www.2biqu.com', '笔趣阁', 'www.52bqg.org', '，最快更新神印王座II皓月当空 ！']  # 替换词表, 用于替换内容中的词
end_words = []  # 结束词表，如果没有遇到所有的这些词，就进入没爬完整处理程序
min_content_len = 10  # 最小段落长度
skip = 0 # 跳过多少章节, 0 表示不跳过, 在下一块执行时该值会自动更新


def content_include_all(content, words=end_words):
    # 内容必须包含所有的词
    for i in words:
        if i not in content:
            return False
    return True


def content_include_any(content, words=end_words):
    # 内容仅需要包含一个词
    for i in words:
        if i in content:
            return True
    return False

def content_replace(content, words=stop_worlds):
    # 替换内容中的词
    for i in words:
        content = content.replace(i, '')
    return content

# %%
if skip >= len(metadata['chapters']):
    print(f'[ERROR] skip={skip} 大于等于章节数')
    raise Exception('skip 大于等于章节数')
    
if skip > 0:
    print(f'skip={skip} 将从第{skip+1}章开始爬取')

for index, c in enumerate(metadata['chapters']):
    if index < skip:
        continue
    print(f'正在爬取第{index+1}章：{c[1]}')
    browser.get(root_url + c[0])

    # 处理防火墙,重定向与弱网的问题
    title_include = c[1] in browser.title
    while not title_include:
        print('    [WARN] 网页标题与章节标题不符，正在刷新...')
        browser.get(root_url + c[0])
        title_include = c[1] in browser.title
        if title_include:
            print('    网页标题与章节标题符合，开始爬取...')
            break

    # 爬取内容
    soup = BeautifulSoup(browser.page_source, 'html.parser')
    title = parser.get_title(soup)
    content = parser.get_content(soup)
    content = content_replace(content)
    content_cut = parser.get_content_cut(content)
    print(f"    页面标题：{title}, 内容长度：{len(content)}, 段落数：{len(content_cut)}")

    # 爬取内容过少或是有可能没爬完整处理程序
    if len(content_cut) < min_content_len or not content_include_all(content):
        print(f'    [WARN] 段落数小于设定值({min_content_len})或是不包含停止词，可能爬取失败')
        print(f'    [WARN] 输出所有段落：')
        for i in content_cut:
            print('    '+str(i))
        print(f'    [WARN] 输出所有段落结束，输入y/yes/skip/continue保存内容并继续爬取，输入任意内容暂停爬取')
        if input().strip() in ['skip', 'continue', 'y', 'yes']:
            continue
        else:
            print(f'[WARN] 已暂停爬取，当前进度：skip={skip}，index={index}')
            break

    # 将内容写入文件
    txtfp.write('---------- \n\n')
    for i in content_cut:
        txtfp.write(i + '\n\n')
    skip = index
    print(f'    当前章爬取完成')
# Out:
# 正在爬取第1章：引子：皓月当空
#     页面标题：引子：皓月当空, 内容长度：1572, 段落数：48
#     当前章爬取完成
# 正在爬取第2章：第一章 龙当当与龙空空
#     页面标题：第一章 龙当当与龙空空, 内容长度：2622, 段落数：63
#     当前章爬取完成
# 正在爬取第3章：第二章 魔法圣殿
#     页面标题：第二章 魔法圣殿, 内容长度：4091, 段落数：83
#     当前章爬取完成
# 正在爬取第4章：第三章 光明庇护体质
#     页面标题：第三章 光明庇护体质, 内容长度：4257, 段落数：70
#     当前章爬取完成
# 正在爬取第5章：第四章 龙家的“两大天才”
#     页面标题：第四章 龙家的“两大天才”, 内容长度：4466, 段落数：87
#     当前章爬取完成
# 正在爬取第6章：第五章 第一堂课
#     页面标题：第五章 第一堂课, 内容长度：3928, 段落数：72
#     当前章爬取完成
# 正在爬取第7章：第六章 圣殿大礼包
#     页面标题：第六章 圣殿大礼包, 内容长度：3980, 段落数：76
#     当前章爬取完成
# 正在爬取第8章：第七章 灵炉，意外
#     页面标题：第七章 灵炉，意外, 内容长度：4355, 段落数：67
#     当前章爬取完成
# 正在爬取第9章：第八章 骑士圣殿也来了
#     页面标题：第八章 骑士圣殿也来了, 内容长度：3902, 段落数：66
#     当前章爬取完成
# 正在爬取第10章：第九章 灵炉，再见灵炉
#     页面标题：第九章 灵炉，再见灵炉, 内容长度：4261, 段落数：79
#     当前章爬取完成
# 正在爬取第11章：第十章 绝望周末？
#     页面标题：第十章 绝望周末？, 内容长度：4255, 段落数：90
#     当前章爬取完成
# 正在爬取第12章：第十一章 骑士圣殿的邋遢骑士
#     页面标题：第十一章 骑士圣殿的邋遢骑士, 内容长度：4011, 段落数：69
#     当前章爬取完成
# 正在爬取第13章：第十二章 悲催的神圣骑士
#     页面标题：第十二章 悲催的神圣骑士, 内容长度：3923, 段落数：67
#     当前章爬取完成
# 正在爬取第14章：第十三章 胆小是优秀的素质
#     页面标题：第十三章 胆小是优秀的素质, 内容长度：4154, 段落数：57
#     当前章爬取完成
# 正在爬取第15章：第十四章 考核的规则
#     页面标题：第十四章 考核的规则, 内容长度：4327, 段落数：69
#     当前章爬取完成
# 正在爬取第16章：第十五章 强者为师的重要性
#     页面标题：第十五章 强者为师的重要性, 内容长度：3954, 段落数：55
#     当前章爬取完成
# 正在爬取第17章：第十六章 天才的世界
#     页面标题：第十六章 天才的世界, 内容长度：4857, 段落数：73
#     当前章爬取完成
# 正在爬取第18章：第十七章 最年轻的法神！
#     页面标题：第十七章 最年轻的法神！, 内容长度：3505, 段落数：60
#     当前章爬取完成
# 正在爬取第19章：第十八章 绿孔雀与莽骑士
#     页面标题：第十八章 绿孔雀与莽骑士, 内容长度：3999, 段落数：64
#     当前章爬取完成
# 正在爬取第20章：第十九章 风的真谛
#     页面标题：第十九章 风的真谛, 内容长度：4239, 段落数：73
#     当前章爬取完成
# 正在爬取第21章：第二十章 觉醒，风元素之子
#     页面标题：第二十章 觉醒，风元素之子, 内容长度：4185, 段落数：61
#     当前章爬取完成
# 正在爬取第22章：第二十一章 莽骑士的教学
#     页面标题：第二十一章 莽骑士的教学, 内容长度：4061, 段落数：79
#     当前章爬取完成
# 正在爬取第23章：第二十二章 联姻？哦，不，结盟！
#     页面标题：第二十二章 联姻？哦，不，结盟！, 内容长度：4228, 段落数：76
#     当前章爬取完成
# 正在爬取第24章：第二十三章 考核开始、考核结束
#     页面标题：第二十三章 考核开始、考核结束, 内容长度：4110, 段落数：77
#     当前章爬取完成
# 正在爬取第25章：第二十四章 四年
#     页面标题：第二十四章 四年, 内容长度：3815, 段落数：68
#     当前章爬取完成
# 正在爬取第26章：第二十五章 兄弟之战
#     页面标题：第二十五章 兄弟之战, 内容长度：4194, 段落数：63
#     当前章爬取完成
# 正在爬取第27章：第二十六章 进阶的灵炉
#     页面标题：第二十六章 进阶的灵炉, 内容长度：3945, 段落数：68
#     当前章爬取完成
# 正在爬取第28章：第二十七章 龙府之秘
#     页面标题：第二十七章 龙府之秘, 内容长度：4181, 段落数：106
#     当前章爬取完成
# 正在爬取第29章：第二十八章 圣城
#     页面标题：第二十八章 圣城, 内容长度：4476, 段落数：84
#     当前章爬取完成
# 正在爬取第30章：第二十九章 灵炉学院
#     页面标题：第二十九章 灵炉学院, 内容长度：4141, 段落数：82
#     当前章爬取完成
# 正在爬取第31章：第三十章 梦中情人
#     页面标题：第三十章 梦中情人, 内容长度：4210, 段落数：82
#     当前章爬取完成
# 正在爬取第32章：第三十一章 赫本
#     页面标题：第三十一章 赫本, 内容长度：4131, 段落数：84
#     当前章爬取完成
# 正在爬取第33章：第三十二章 第一堂课
#     页面标题：第三十二章 第一堂课, 内容长度：4276, 段落数：78
#     当前章爬取完成
# 正在爬取第34章：第三十三章 谁也不能伤害我弟弟
#     页面标题：第三十三章 谁也不能伤害我弟弟, 内容长度：3895, 段落数：64
#     当前章爬取完成
# 正在爬取第35章：第三十四章 元素圣女
#     页面标题：第三十四章 元素圣女, 内容长度：4221, 段落数：76
#     当前章爬取完成
# 正在爬取第36章：第三十五章 暴力美学
#     页面标题：第三十五章 暴力美学, 内容长度：4083, 段落数：79
#     当前章爬取完成
# 正在爬取第37章：第三十六章 空空，砍我
#     页面标题：第三十六章 空空，砍我, 内容长度：4012, 段落数：58
#     当前章爬取完成
# 正在爬取第38章：第三十七章 集体爆发的骑士一班
#     页面标题：第三十七章 集体爆发的骑士一班, 内容长度：3981, 段落数：64
#     当前章爬取完成
# 正在爬取第39章：第三十八章 圣殿修炼室的修炼
#     页面标题：第三十八章 圣殿修炼室的修炼, 内容长度：4310, 段落数：57
#     当前章爬取完成
# 正在爬取第40章：第三十九章 女神赫本
#     页面标题：第三十九章 女神赫本, 内容长度：4093, 段落数：82
#     当前章爬取完成
# 正在爬取第41章：第四十章 神女梦露
#     页面标题：第四十章 神女梦露, 内容长度：4013, 段落数：80
#     当前章爬取完成
# 正在爬取第42章：第四十一章 考核，选人！
#     页面标题：第四十一章 考核，选人！, 内容长度：4250, 段落数：83
#     当前章爬取完成
# 正在爬取第43章：第四十二章 表姐威武！考核开始！
#     页面标题：第四十二章 表姐威武！考核开始！, 内容长度：4058, 段落数：82
#     当前章爬取完成
# 正在爬取第44章：第四十三章 大战魔族
#     页面标题：第四十三章 大战魔族, 内容长度：4154, 段落数：62
#     当前章爬取完成
# 正在爬取第45章：第四十四章 完美配合
#     页面标题：第四十四章 完美配合, 内容长度：4167, 段落数：74
#     当前章爬取完成
# 正在爬取第46章：第四十五章 太恶心、太美妙了……
#     页面标题：第四十五章 太恶心、太美妙了……, 内容长度：4189, 段落数：77
#     当前章爬取完成
# 正在爬取第47章：第四十六章 天使降临
#     页面标题：第四十六章 天使降临, 内容长度：4074, 段落数：66
#     当前章爬取完成
# 正在爬取第48章：第四十七章 大恶魔
#     页面标题：第四十七章 大恶魔, 内容长度：4177, 段落数：90
#     当前章爬取完成
# 正在爬取第49章：第四十八章 梦露的底牌
#     页面标题：第四十八章 梦露的底牌, 内容长度：4171, 段落数：78
#     当前章爬取完成
# 正在爬取第50章：第四十九章 最后一组
#     页面标题：第四十九章 最后一组, 内容长度：4143, 段落数：90
#     当前章爬取完成
# 正在爬取第51章：第五十章 年级第一
#     页面标题：第五十章 年级第一, 内容长度：4270, 段落数：72
#     当前章爬取完成
# 正在爬取第52章：第五十一章 年级冠军的特殊嘉奖
#     页面标题：第五十一章 年级冠军的特殊嘉奖, 内容长度：4104, 段落数：65
#     当前章爬取完成
# 正在爬取第53章：第五十二章 秀色可餐
#     页面标题：第五十二章 秀色可餐, 内容长度：4215, 段落数：87
#     当前章爬取完成
# 正在爬取第54章：第五十三章 灵炉天选开始
#     页面标题：第五十三章 灵炉天选开始, 内容长度：4889, 段落数：94
#     当前章爬取完成
# 正在爬取第55章：第五十四章 月明沧海灵炉
#     页面标题：第五十四章 月明沧海灵炉, 内容长度：3369, 段落数：55
#     当前章爬取完成
# 正在爬取第56章：第五十五章 神祈屿桐灵炉
#     页面标题：第五十五章 神祈屿桐灵炉, 内容长度：4232, 段落数：86
#     当前章爬取完成
# 正在爬取第57章：第五十六章 第十智慧灵炉
#     页面标题：第五十六章 第十智慧灵炉, 内容长度：4089, 段落数：64
#     当前章爬取完成
# 正在爬取第58章：第五十七章 光明天使灵炉
#     页面标题：第五十七章 光明天使灵炉, 内容长度：4205, 段落数：74
#     当前章爬取完成
# 正在爬取第59章：第五十八章 月明沧海的能力
#     页面标题：第五十八章 月明沧海的能力, 内容长度：4172, 段落数：72
#     当前章爬取完成
# 正在爬取第60章：第五十九章 神祈屿桐，元涡进化
#     页面标题：第五十九章 神祈屿桐，元涡进化, 内容长度：4111, 段落数：80
#     当前章爬取完成
# 正在爬取第61章：第六十章 场景再现
#     页面标题：第六十章 场景再现, 内容长度：4496, 段落数：77
#     当前章爬取完成
# 正在爬取第62章：第六十一章 天渊领域
#     页面标题：第六十一章 天渊领域, 内容长度：4457, 段落数：95
#     当前章爬取完成
# 正在爬取第63章：第六十二章 灵力化液
#     页面标题：第六十二章 灵力化液, 内容长度：3815, 段落数：59
#     当前章爬取完成
# 正在爬取第64章：第六十三章 龙当当，你这个渣男！
#     页面标题：第六十三章 龙当当，你这个渣男！, 内容长度：4130, 段落数：66
#     当前章爬取完成
# 正在爬取第65章：第六十四章 圣堂召唤
#     页面标题：第六十四章 圣堂召唤, 内容长度：4187, 段落数：84
#     当前章爬取完成
# 正在爬取第66章：第六十五章 后备圣堂
#     页面标题：第六十五章 后备圣堂, 内容长度：4186, 段落数：57
#     当前章爬取完成
# 正在爬取第67章：第六十六章 约战
#     页面标题：第六十六章 约战, 内容长度：4087, 段落数：79
#     当前章爬取完成
# 正在爬取第68章：第六十七章 天渊之海
#     页面标题：第六十七章 天渊之海, 内容长度：4147, 段落数：71
#     当前章爬取完成
# 正在爬取第69章：第六十八章 神祈，沧月天使
#     页面标题：第六十八章 神祈，沧月天使, 内容长度：4310, 段落数：60
#     当前章爬取完成
# 正在爬取第70章：第六十九章 再战魔族
#     页面标题：第六十九章 再战魔族, 内容长度：4008, 段落数：76
#     当前章爬取完成
# 正在爬取第71章：第七十章 真正的融合魔法
#     页面标题：第七十章 真正的融合魔法, 内容长度：4188, 段落数：75
#     当前章爬取完成
# 正在爬取第72章：第七十一章 表姐再威武！
#     页面标题：第七十一章 表姐再威武！, 内容长度：4077, 段落数：70
#     当前章爬取完成
# 正在爬取第73章：第七十二章 七阶之威！
#     页面标题：第七十二章 七阶之威！, 内容长度：4208, 段落数：79
#     当前章爬取完成
# 正在爬取第74章：第七十三章 战斗的神祇沧月天使
#     页面标题：第七十三章 战斗的神祇沧月天使, 内容长度：4116, 段落数：71
#     当前章爬取完成
# 正在爬取第75章：第七十四章 什么？有帅哥？
#     页面标题：第七十四章 什么？有帅哥？, 内容长度：4178, 段落数：79
#     当前章爬取完成
# 正在爬取第76章：第七十五章 同学聚会？
#     页面标题：第七十五章 同学聚会？, 内容长度：4227, 段落数：94
#     当前章爬取完成
# 正在爬取第77章：第七十六章 目的不纯
#     页面标题：第七十六章 目的不纯, 内容长度：4123, 段落数：59
#     当前章爬取完成
# 正在爬取第78章：第七十七章 沧月化铠，神祈变身
#     页面标题：第七十七章 沧月化铠，神祈变身, 内容长度：4172, 段落数：72
#     当前章爬取完成
# 正在爬取第79章：第七十八章 神祈天使龙当当
#     页面标题：第七十八章 神祈天使龙当当, 内容长度：3971, 段落数：79
#     当前章爬取完成
# 正在爬取第80章：第七十九章 亡灵潮汐
#     页面标题：第七十九章 亡灵潮汐, 内容长度：4014, 段落数：65
#     当前章爬取完成
# 正在爬取第81章：第八十章 龙空空是救世主?
#     页面标题：第八十章 龙空空是救世主?, 内容长度：3731, 段落数：50
#     当前章爬取完成
# 正在爬取第82章：第八十一章 九大灵窍
#     页面标题：第八十一章 九大灵窍, 内容长度：4120, 段落数：63
#     当前章爬取完成
# 正在爬取第83章：第八十二章 妈妈的身世
#     页面标题：第八十二章 妈妈的身世, 内容长度：3918, 段落数：57
#     当前章爬取完成
# 正在爬取第84章：第八十三章 亡灵潮真正的状态
#     页面标题：第八十三章 亡灵潮真正的状态, 内容长度：3826, 段落数：38
#     当前章爬取完成
# 正在爬取第85章：第八十四章 外公的馈赠
#     页面标题：第八十四章 外公的馈赠, 内容长度：3925, 段落数：56
#     当前章爬取完成
# 正在爬取第86章：第八十五章 不是亲表姐?
#     页面标题：第八十五章 不是亲表姐?, 内容长度：3999, 段落数：64
#     当前章爬取完成
# 正在爬取第87章：第八十六章 想做生意的龙空空
#     页面标题：第八十六章 想做生意的龙空空, 内容长度：3890, 段落数：70
#     当前章爬取完成
# 正在爬取第88章：第八十七章 你的辞职我批准了!
#     页面标题：第八十七章 你的辞职我批准了!, 内容长度：3806, 段落数：76
#     当前章爬取完成
# 正在爬取第89章：第八十八章 真正的实战考核
#     页面标题：第八十八章 真正的实战考核, 内容长度：4266, 段落数：87
#     当前章爬取完成
# 正在爬取第90章：第八十九章 首战亡灵
#     页面标题：第八十九章 首战亡灵, 内容长度：3731, 段落数：63
#     当前章爬取完成
# 正在爬取第91章：第九十章 难度陡增
#     页面标题：第九十章 难度陡增, 内容长度：3964, 段落数：78
#     当前章爬取完成
# 正在爬取第92章：第九十一章 绝境？
#     页面标题：第九十一章 绝境？, 内容长度：4231, 段落数：64
#     当前章爬取完成
# 正在爬取第93章：第九十二章 怨灵来袭
#     页面标题：第九十二章 怨灵来袭, 内容长度：4125, 段落数：71
#     当前章爬取完成
# 正在爬取第94章：第九十三章 强大的巫妖！
#     页面标题：第九十三章 强大的巫妖！, 内容长度：4042, 段落数：58
#     当前章爬取完成
# 正在爬取第95章：第九十四章 击杀巫妖
#     页面标题：第九十四章 击杀巫妖, 内容长度：4271, 段落数：66
#     当前章爬取完成
# 正在爬取第96章：第九十五章 最后一个任务
#     页面标题：第九十五章 最后一个任务, 内容长度：4130, 段落数：63
#     当前章爬取完成
# 正在爬取第97章：第九十六章 大战荆门村
#     页面标题：第九十六章 大战荆门村, 内容长度：4279, 段落数：71
#     当前章爬取完成
# 正在爬取第98章：第九十七章 冰与火龙歌
#     页面标题：第九十七章 冰与火龙歌, 内容长度：4123, 段落数：60
#     当前章爬取完成
# 正在爬取第99章：第九十八章 轮回之子
#     页面标题：第九十八章 轮回之子, 内容长度：4186, 段落数：63
#     当前章爬取完成
# 正在爬取第100章：第九十九章 地涌金莲
#     页面标题：第九十九章 地涌金莲, 内容长度：4090, 段落数：73
#     当前章爬取完成
# 正在爬取第101章：第一百章 不可能完成的任务
#     页面标题：第一百章 不可能完成的任务, 内容长度：4220, 段落数：69
#     当前章爬取完成
# 正在爬取第102章：第一百零一章 禁！光之礼赞
#     页面标题：第一百零一章 禁！光之礼赞, 内容长度：3998, 段落数：77
#     当前章爬取完成
# 正在爬取第103章：第一百零二章 战后
#     页面标题：第一百零二章 战后, 内容长度：4312, 段落数：74
#     当前章爬取完成
# 正在爬取第104章：第一百零三章 三姐弟的秘聊
#     页面标题：第一百零三章 三姐弟的秘聊, 内容长度：4160, 段落数：75
#     当前章爬取完成
# 正在爬取第105章：第一百零四章 要去获得坐骑了？
#     页面标题：第一百零四章 要去获得坐骑了？, 内容长度：4142, 段落数：89
#     当前章爬取完成
# 正在爬取第106章：第一百零五章 骑士圣山
#     页面标题：第一百零五章 骑士圣山, 内容长度：4002, 段落数：62
#     当前章爬取完成
# 正在爬取第107章：第一百零六章 我不配和你不配
#     页面标题：第一百零六章 我不配和你不配, 内容长度：4402, 段落数：88
#     当前章爬取完成
# 正在爬取第108章：第一百零七章 五爪金龙
#     页面标题：第一百零七章 五爪金龙, 内容长度：3826, 段落数：72
#     当前章爬取完成
# 正在爬取第109章：第一百零八章 龙皇相邀
#     页面标题：第一百零八章 龙皇相邀, 内容长度：3975, 段落数：66
#     当前章爬取完成
# 正在爬取第110章：第一百零九章 龙当当的坐骑伙伴
#     页面标题：第一百零九章 龙当当的坐骑伙伴, 内容长度：3568, 段落数：56
#     当前章爬取完成
# 正在爬取第111章：第一百一十章 龙空空的坐骑伙伴
#     页面标题：第一百一十章 龙空空的坐骑伙伴, 内容长度：3972, 段落数：70
#     当前章爬取完成
# 正在爬取第112章：第一百一十一章 龙兄鼠弟
#     页面标题：第一百一十一章 龙兄鼠弟, 内容长度：3934, 段落数：80
#     当前章爬取完成
# 正在爬取第113章：第一百一十二章 鼠大王的天赋技能
#     页面标题：第一百一十二章 鼠大王的天赋技能, 内容长度：4186, 段落数：84
#     当前章爬取完成
# 正在爬取第114章：第一百一十三章 第四位龙骑士
#     页面标题：第一百一十三章 第四位龙骑士, 内容长度：2328, 段落数：55
#     当前章爬取完成
# 正在爬取第115章：第一百一十四章 龙皇骑士
#     页面标题：第一百一十四章 龙皇骑士, 内容长度：5483, 段落数：93
#     当前章爬取完成
# 正在爬取第116章：第一百一十五章 老师们回来了
#     页面标题：第一百一十五章 老师们回来了, 内容长度：4078, 段落数：63
#     当前章爬取完成
# 正在爬取第117章：第一百一十六章 不靠谱的王快乐
#     页面标题：第一百一十六章 不靠谱的王快乐, 内容长度：4055, 段落数：82
#     当前章爬取完成
# 正在爬取第118章：第一百一十七章 圣堂堂主
#     页面标题：第一百一十七章 圣堂堂主, 内容长度：3953, 段落数：53
#     当前章爬取完成
# 正在爬取第119章：第一百一十八章 猎魔团选拔赛开始
#     页面标题：第一百一十八章 猎魔团选拔赛开始, 内容长度：3767, 段落数：48
#     当前章爬取完成
# 正在爬取第120章：第一百一十九章 淘汰赛第一轮
#     页面标题：第一百一十九章 淘汰赛第一轮, 内容长度：2912, 段落数：49
#     当前章爬取完成
# 正在爬取第121章：第一百二十章 龙当当首战
#     页面标题：第一百二十章 龙当当首战, 内容长度：3863, 段落数：79
#     当前章爬取完成
# 正在爬取第122章：第一百二十一章 灵炉融合技
#     页面标题：第一百二十一章 灵炉融合技, 内容长度：4127, 段落数：58
#     当前章爬取完成
# 正在爬取第123章：第一百二十二章 耀阳
#     页面标题：第一百二十二章 耀阳, 内容长度：4033, 段落数：67
#     当前章爬取完成
# 正在爬取第124章：第一百二十三章 绿甲女子
#     页面标题：第一百二十三章 绿甲女子, 内容长度：4145, 段落数：60
#     当前章爬取完成
# 正在爬取第125章：第一百二十四章 活下来了
#     页面标题：第一百二十四章 活下来了, 内容长度：4189, 段落数：79
#     当前章爬取完成
# 正在爬取第126章：第一百二十五章 三号和五号
#     页面标题：第一百二十五章 三号和五号, 内容长度：4239, 段落数：56
#     当前章爬取完成
# 正在爬取第127章：第一百二十六章 圣引天渊
#     页面标题：第一百二十六章 圣引天渊, 内容长度：4018, 段落数：58
#     当前章爬取完成
# 正在爬取第128章：第一百二十七章 梦里啥都有
#     页面标题：第一百二十七章 梦里啥都有, 内容长度：4188, 段落数：74
#     当前章爬取完成
# 正在爬取第129章：第一百二十八章 六阶辉耀骑士
#     页面标题：第一百二十八章 六阶辉耀骑士, 内容长度：4082, 段落数：56
#     当前章爬取完成
# 正在爬取第130章：第一百二十九章 九柄圣剑
#     页面标题：第一百二十九章 九柄圣剑, 内容长度：4170, 段落数：65
#     当前章爬取完成
# 正在爬取第131章：第一百三十章 海纪枫的路
#     页面标题：第一百三十章 海纪枫的路, 内容长度：4056, 段落数：37
#     当前章爬取完成
# 正在爬取第132章：第一百三十一章 龙当当要表白？
#     页面标题：第一百三十一章 龙当当要表白？, 内容长度：4182, 段落数：53
#     当前章爬取完成
# 正在爬取第133章：第一百三十二章 复赛开始
#     页面标题：第一百三十二章 复赛开始, 内容长度：4116, 段落数：67
#     当前章爬取完成
# 正在爬取第134章：第一百三十三章 灵炉也有爸爸？
#     页面标题：第一百三十三章 灵炉也有爸爸？, 内容长度：4088, 段落数：67
#     当前章爬取完成
# 正在爬取第135章：第一百三十四章 三王盾
#     页面标题：第一百三十四章 三王盾, 内容长度：4076, 段落数：44
#     当前章爬取完成
# 正在爬取第136章：第一百三十五章 三王咆哮
#     页面标题：第一百三十五章 三王咆哮, 内容长度：4109, 段落数：50
#     当前章爬取完成
# 正在爬取第137章：第一百三十六章 残暴的鼠大王
#     页面标题：第一百三十六章 残暴的鼠大王, 内容长度：4091, 段落数：75
#     当前章爬取完成
# 正在爬取第138章：第一百三十七章 鼠大王又悲剧了
#     页面标题：第一百三十七章 鼠大王又悲剧了, 内容长度：3596, 段落数：56
#     当前章爬取完成
# 正在爬取第139章：第一百三十八章 鼠大王的悲伤与快乐
#     页面标题：第一百三十八章 鼠大王的悲伤与快乐, 内容长度：4281, 段落数：68
#     当前章爬取完成
# 正在爬取第140章：第一百三十九章 威慑三王
#     页面标题：第一百三十九章 威慑三王, 内容长度：3898, 段落数：61
#     当前章爬取完成
# 正在爬取第141章：第一百四十章 霸天槌
#     页面标题：第一百四十章 霸天槌, 内容长度：3979, 段落数：60
#     当前章爬取完成
# 正在爬取第142章：第一百四十一章 强势的元素圣女
#     页面标题：第一百四十一章 强势的元素圣女, 内容长度：3972, 段落数：75
#     当前章爬取完成
# 正在爬取第143章：第一百四十二章 决赛第一轮
#     页面标题：第一百四十二章 决赛第一轮, 内容长度：3956, 段落数：68
#     当前章爬取完成
# 正在爬取第144章：第一百四十三章 魔法骑士龙当当
#     页面标题：第一百四十三章 魔法骑士龙当当, 内容长度：3373, 段落数：48
#     当前章爬取完成
# 正在爬取第145章：第一百四十四章 龙当当的套餐
#     页面标题：第一百四十四章 龙当当的套餐, 内容长度：4442, 段落数：78
#     当前章爬取完成
# 正在爬取第146章：第一百四十五章 巫谛、巫帝
#     页面标题：第一百四十五章 巫谛、巫帝, 内容长度：3965, 段落数：80
#     当前章爬取完成
# 正在爬取第147章：第一百四十六章 记名弟子
#     页面标题：第一百四十六章 记名弟子, 内容长度：4038, 段落数：54
#     当前章爬取完成
# 正在爬取第148章：第一百四十七章 前三名的奖励
#     页面标题：第一百四十七章 前三名的奖励, 内容长度：3928, 段落数：62
#     当前章爬取完成
# 正在爬取第149章：第一百四十八章 全面压制
#     页面标题：第一百四十八章 全面压制, 内容长度：3863, 段落数：64
#     当前章爬取完成
# 正在爬取第150章：第一百四十九章 子桑琉荧的第三灵炉
#     页面标题：第一百四十九章 子桑琉荧的第三灵炉, 内容长度：3888, 段落数：75
#     当前章爬取完成
# 正在爬取第151章：第一百五十章 神女之威
#     页面标题：第一百五十章 神女之威, 内容长度：3968, 段落数：67
#     当前章爬取完成
# 正在爬取第152章：第一百五十一章 团队雏形
#     页面标题：第一百五十一章 团队雏形, 内容长度：4190, 段落数：60
#     当前章爬取完成
# 正在爬取第153章：第一百五十二章 月蚀
#     页面标题：第一百五十二章 月蚀, 内容长度：4181, 段落数：58
#     当前章爬取完成
# 正在爬取第154章：第一百五十三章 选人
#     页面标题：第一百五十三章 选人, 内容长度：4141, 段落数：69
#     当前章爬取完成
# 正在爬取第155章：第一百五十四章 猎魔者三件套
#     页面标题：第一百五十四章 猎魔者三件套, 内容长度：4236, 段落数：51
#     当前章爬取完成
# 正在爬取第156章：第一百五十五章 灵晶在线
#     页面标题：第一百五十五章 灵晶在线, 内容长度：4048, 段落数：83
#     当前章爬取完成
# 正在爬取第157章：第一百五十六章 聊天也是一种修行
#     页面标题：第一百五十六章 聊天也是一种修行, 内容长度：4012, 段落数：91
#     当前章爬取完成
# 正在爬取第158章：第一百五十七章 皓月当空的团长
#     页面标题：第一百五十七章 皓月当空的团长, 内容长度：4273, 段落数：95
#     当前章爬取完成
# 正在爬取第159章：第一百五十八章 内外兼修，血炼金身
#     页面标题：第一百五十八章 内外兼修，血炼金身, 内容长度：4004, 段落数：33
#     当前章爬取完成
# 正在爬取第160章：第一百五十九章 聊天炼分神？
#     页面标题：第一百五十九章 聊天炼分神？, 内容长度：3998, 段落数：80
#     当前章爬取完成
# 正在爬取第161章：第一百六十章 意料之外的血炼金身
#     页面标题：第一百六十章 意料之外的血炼金身, 内容长度：4158, 段落数：66
#     当前章爬取完成
# 正在爬取第162章：第一百六十一章 外灵力测试
#     页面标题：第一百六十一章 外灵力测试, 内容长度：4575, 段落数：79
#     当前章爬取完成
# 正在爬取第163章：第一百六十二章 试血
#     页面标题：第一百六十二章 试血, 内容长度：4411, 段落数：63
#     当前章爬取完成
# 正在爬取第164章：第一百六十三章 唯有龙系？
#     页面标题：第一百六十三章 唯有龙系？, 内容长度：4559, 段落数：66
#     当前章爬取完成
# 正在爬取第165章：第一百六十四章 确认猜想
#     页面标题：第一百六十四章 确认猜想, 内容长度：4128, 段落数：83
#     当前章爬取完成
# 正在爬取第166章：第一百六十五章 圣城大拍卖场
#     页面标题：第一百六十五章 圣城大拍卖场, 内容长度：4166, 段落数：78
#     当前章爬取完成
# 正在爬取第167章：第一百六十六章 外灵力暴增
#     页面标题：第一百六十六章 外灵力暴增, 内容长度：4201, 段落数：69
#     当前章爬取完成
# 正在爬取第168章：第一百六十七章 觉醒，血脉天赋
#     页面标题：第一百六十七章 觉醒，血脉天赋, 内容长度：4025, 段落数：64
#     当前章爬取完成
# 正在爬取第169章：第一百六十八章 魔鬼、疯子、女妖
#     页面标题：第一百六十八章 魔鬼、疯子、女妖, 内容长度：3809, 段落数：54
#     当前章爬取完成
# 正在爬取第170章：第一百六十九章 魔兽森林
#     页面标题：第一百六十九章 魔兽森林, 内容长度：3849, 段落数：55
#     当前章爬取完成
# 正在爬取第171章：第一百七十章 奖励与惩罚
#     页面标题：第一百七十章 奖励与惩罚, 内容长度：3817, 段落数：54
#     当前章爬取完成
# 正在爬取第172章：第一百七十一章 彼此熟悉
#     页面标题：第一百七十一章 彼此熟悉, 内容长度：4018, 段落数：56
#     当前章爬取完成
# 正在爬取第173章：第一百七十二章 十二守望者之雄霸天下灵炉
#     页面标题：第一百七十二章 十二守望者之雄霸天下灵炉, 内容长度：4027, 段落数：75
#     当前章爬取完成
# 正在爬取第174章：第一百七十三章 鼠吞蛇
#     页面标题：第一百七十三章 鼠吞蛇, 内容长度：3906, 段落数：64
#     当前章爬取完成
# 正在爬取第175章：第一百七十四章 光明狮鹫
#     页面标题：第一百七十四章 光明狮鹫, 内容长度：3800, 段落数：67
#     当前章爬取完成
# 正在爬取第176章：第一百七十五章 光明狮鹫的恐怖之处
#     页面标题：第一百七十五章 光明狮鹫的恐怖之处, 内容长度：3862, 段落数：63
#     当前章爬取完成
# 正在爬取第177章：第一百七十六章 不装了，摊牌了!
#     页面标题：第一百七十六章 不装了，摊牌了!, 内容长度：3855, 段落数：71
#     当前章爬取完成
# 正在爬取第178章：第一百七十七章 至诚契约
#     页面标题：第一百七十七章 至诚契约, 内容长度：3887, 段落数：59
#     当前章爬取完成
# 正在爬取第179章：第一百七十八章 求援信号
#     页面标题：第一百七十八章 求援信号, 内容长度：3933, 段落数：60
#     当前章爬取完成
# 正在爬取第180章：第一百七十九章 八级魔风猴
#     页面标题：第一百七十九章 八级魔风猴, 内容长度：3956, 段落数：69
#     当前章爬取完成
# 正在爬取第181章：第一百八十章 救援
#     页面标题：第一百八十章 救援, 内容长度：3665, 段落数：57
#     当前章爬取完成
# 正在爬取第182章：第一百八十一章 任性就任性吧
#     页面标题：第一百八十一章 任性就任性吧, 内容长度：4078, 段落数：70
#     当前章爬取完成
# 正在爬取第183章：第一百八十二章 兽潮
#     页面标题：第一百八十二章 兽潮, 内容长度：4180, 段落数：74
#     当前章爬取完成
# 正在爬取第184章：第一百八十三章 血魔虎
#     页面标题：第一百八十三章 血魔虎, 内容长度：4166, 段落数：81
#     当前章爬取完成
# 正在爬取第185章：第一百八十四章 紫色光环
#     页面标题：第一百八十四章 紫色光环, 内容长度：4212, 段落数：67
#     当前章爬取完成
# 正在爬取第186章：第一百八十五章 大丰收
#     页面标题：第一百八十五章 大丰收, 内容长度：4020, 段落数：50
#     当前章爬取完成
# 正在爬取第187章：第一百八十六章 风暴魔龙
#     页面标题：第一百八十六章 风暴魔龙, 内容长度：4090, 段落数：63
#     当前章爬取完成
# 正在爬取第188章：第一百八十七章 考验的题目
#     页面标题：第一百八十七章 考验的题目, 内容长度：4009, 段落数：69
#     当前章爬取完成
# 正在爬取第189章：第一百八十八章 九级雷震鸟
#     页面标题：第一百八十八章 九级雷震鸟, 内容长度：4130, 段落数：63
#     当前章爬取完成
# 正在爬取第190章：第一百八十九章 龙空空的“紫色”
#     页面标题：第一百八十九章 龙空空的“紫色”, 内容长度：4079, 段落数：55
#     当前章爬取完成
# 正在爬取第191章：第一百九十章 那是‘守护’的力量？
#     页面标题：第一百九十章 那是‘守护’的力量？, 内容长度：4108, 段落数：60
#     当前章爬取完成
# 正在爬取第192章：第一百九十一章 天风魔猿
#     页面标题：第一百九十一章 天风魔猿, 内容长度：4143, 段落数：55
#     当前章爬取完成
# 正在爬取第193章：第一百九十二章 第一阶段结束
#     页面标题：第一百九十二章 第一阶段结束, 内容长度：3883, 段落数：66
#     当前章爬取完成
# 正在爬取第194章：第一百九十三章 去女神家
#     页面标题：第一百九十三章 去女神家, 内容长度：3963, 段落数：64
#     当前章爬取完成
# 正在爬取第195章：第一百九十四章 第二阶段即将开始
#     页面标题：第一百九十四章 第二阶段即将开始, 内容长度：3877, 段落数：65
#     当前章爬取完成
# 正在爬取第196章：第一百九十五章 三项考核
#     页面标题：第一百九十五章 三项考核, 内容长度：3925, 段落数：64
#     当前章爬取完成
# 正在爬取第197章：第一百九十六章 潜水
#     页面标题：第一百九十六章 潜水, 内容长度：3995, 段落数：54
#     当前章爬取完成
# 正在爬取第198章：第一百九十七章 两个人一条命
#     页面标题：第一百九十七章 两个人一条命, 内容长度：3606, 段落数：60
#     当前章爬取完成
# 正在爬取第199章：第一百九十八章 如此近距离的接触
#     页面标题：第一百九十八章 如此近距离的接触, 内容长度：3912, 段落数：63
#     当前章爬取完成
# 正在爬取第200章：第一百九十九章 第二关
#     页面标题：第一百九十九章 第二关, 内容长度：3741, 段落数：81
#     当前章爬取完成
# 正在爬取第201章：第二百章 五层精神之海?
#     页面标题：第二百章 五层精神之海?, 内容长度：3759, 段落数：66
#     当前章爬取完成
# 正在爬取第202章：第二百零一章 分身的精神边际
#     页面标题：第二百零一章 分身的精神边际, 内容长度：3921, 段落数：66
#     当前章爬取完成
# 正在爬取第203章：第二百零二章 龙当当的恐怖之处
#     页面标题：第二百零二章 龙当当的恐怖之处, 内容长度：3951, 段落数：69
#     当前章爬取完成
# 正在爬取第204章：第二百零三章 我们缺功勋值吗?
#     页面标题：第二百零三章 我们缺功勋值吗?, 内容长度：3919, 段落数：59
#     当前章爬取完成
# 正在爬取第205章：第二百零四章 很贵的一战
#     页面标题：第二百零四章 很贵的一战, 内容长度：3967, 段落数：64
#     当前章爬取完成
# 正在爬取第206章：第二百零五章 龙当当的布局
#     页面标题：第二百零五章 龙当当的布局, 内容长度：3597, 段落数：47
#     当前章爬取完成
# 正在爬取第207章：第二百零六章 强势过关
#     页面标题：第二百零六章 强势过关, 内容长度：3361, 段落数：51
#     当前章爬取完成
# 正在爬取第208章：第二百零七章 正心殿
#     页面标题：第二百零七章 正心殿, 内容长度：3896, 段落数：70
#     当前章爬取完成
# 正在爬取第209章：第二百零八章 守心
#     页面标题：第二百零八章 守心, 内容长度：3792, 段落数：63
#     当前章爬取完成
# 正在爬取第210章：第二百零九章 正式成为猎魔者
#     页面标题：第二百零九章 正式成为猎魔者, 内容长度：3590, 段落数：59
#     当前章爬取完成
# 正在爬取第211章：第二百一十章 士级猎魔团
#     页面标题：第二百一十章 士级猎魔团, 内容长度：4037, 段落数：77
#     当前章爬取完成
# 正在爬取第212章：第二百一十一章 兑换奖励
#     页面标题：第二百一十一章 兑换奖励, 内容长度：3945, 段落数：53
#     当前章爬取完成
# 正在爬取第213章：第二百一十二章 套装，圣耀之心
#     页面标题：第二百一十二章 套装，圣耀之心, 内容长度：4166, 段落数：78
#     当前章爬取完成
# 正在爬取第214章：第二百一十四章 龙当当想要的奖励
#     页面标题：第二百一十四章 龙当当想要的奖励, 内容长度：3577, 段落数：56
#     当前章爬取完成
# 正在爬取第215章：第二百一十五章 幸福中翱翔
#     页面标题：第二百一十五章 幸福中翱翔, 内容长度：4182, 段落数：65
#     当前章爬取完成
# 正在爬取第216章：第二百一十六章 新装备
#     页面标题：第二百一十六章 新装备, 内容长度：3900, 段落数：59
#     当前章爬取完成
# 正在爬取第217章：第二百一十七章 突破六阶
#     页面标题：第二百一十七章 突破六阶, 内容长度：4213, 段落数：91
#     当前章爬取完成
# 正在爬取第218章：第二百一十八章 紧急任务
#     页面标题：第二百一十八章 紧急任务, 内容长度：4169, 段落数：85
#     当前章爬取完成
# 正在爬取第219章：第二百一十九章 神女之威
#     页面标题：第二百一十九章 神女之威, 内容长度：4085, 段落数：73
#     当前章爬取完成
# 正在爬取第220章：第二百二十章 陷阱，绝境？
#     页面标题：第二百二十章 陷阱，绝境？, 内容长度：4116, 段落数：66
#     当前章爬取完成
# 正在爬取第221章：第二百二十一章 击杀八阶亡者
#     页面标题：第二百二十一章 击杀八阶亡者, 内容长度：4152, 段落数：63
#     当前章爬取完成
# 正在爬取第222章：第二百二十二章 这个戏法是怎么变的？
#     页面标题：第二百二十二章 这个戏法是怎么变的？, 内容长度：4145, 段落数：64
#     当前章爬取完成
# 正在爬取第223章：第二百二十三章 奖励？惩罚？
#     页面标题：第二百二十三章 奖励？惩罚？, 内容长度：4133, 段落数：70
#     当前章爬取完成
# 正在爬取第224章：第二百二十四章 静坐与条幅
#     页面标题：第二百二十四章 静坐与条幅, 内容长度：4164, 段落数：81
#     当前章爬取完成
# 正在爬取第225章：第二百二十五章 惩罚解除
#     页面标题：第二百二十五章 惩罚解除, 内容长度：4197, 段落数：65
#     当前章爬取完成
# 正在爬取第226章：第二百二十六章 小八的变化
#     页面标题：第二百二十六章 小八的变化, 内容长度：4053, 段落数：54
#     当前章爬取完成
# 正在爬取第227章：第二百二十七章 三头黄金龙
#     页面标题：第二百二十七章 三头黄金龙, 内容长度：4149, 段落数：65
#     当前章爬取完成
# 正在爬取第228章：第二百二十八章 圣殿召唤
#     页面标题：第二百二十八章 圣殿召唤, 内容长度：4149, 段落数：67
#     当前章爬取完成
# 正在爬取第229章：第二百二十九章 再战魔族
#     页面标题：第二百二十九章 再战魔族, 内容长度：4168, 段落数：57
#     当前章爬取完成
# 正在爬取第230章：第二百三十章 鼠大王再出山
#     页面标题：第二百三十章 鼠大王再出山, 内容长度：4089, 段落数：63
#     当前章爬取完成
# 正在爬取第231章：第二百三十一章 如此美好的修炼时光
#     页面标题：第二百三十一章 如此美好的修炼时光, 内容长度：4060, 段落数：66
#     当前章爬取完成
# 正在爬取第232章：第二百三十二章 三头黄金龙之威
#     页面标题：第二百三十二章 三头黄金龙之威, 内容长度：4182, 段落数：65
#     当前章爬取完成
# 正在爬取第233章：第二百三十三章 军团级别的魔族
#     页面标题：第二百三十三章 军团级别的魔族, 内容长度：4180, 段落数：68
#     当前章爬取完成
# 正在爬取第234章：第二百三十四章 第七关
#     页面标题：第二百三十四章 第七关, 内容长度：4168, 段落数：74
#     当前章爬取完成
# 正在爬取第235章：第二百三十五章 激战恶魔族
#     页面标题：第二百三十五章 激战恶魔族, 内容长度：4238, 段落数：82
#     当前章爬取完成
# 正在爬取第236章：第二百三十六章 第七十二柱魔神
#     页面标题：第二百三十六章 第七十二柱魔神, 内容长度：4205, 段落数：78
#     当前章爬取完成
# 正在爬取第237章：第二百三十七章 龙空空，毁灭变身
#     页面标题：第二百三十七章 龙空空，毁灭变身, 内容长度：4247, 段落数：73
#     当前章爬取完成
# 正在爬取第238章：第二百三十八章 第四位龙骑士？
#     页面标题：第二百三十八章 第四位龙骑士？, 内容长度：4192, 段落数：66
#     当前章爬取完成
# 正在爬取第239章：第二百三十九章 来吧，展示！
#     页面标题：第二百三十九章 来吧，展示！, 内容长度：4160, 段落数：56
#     当前章爬取完成
# 正在爬取第240章：第二百四十章 身体里的力量？
#     页面标题：第二百四十章 身体里的力量？, 内容长度：3678, 段落数：67
#     当前章爬取完成
# 正在爬取第241章：第二百四十一章 骑士圣殿的灵炉
#     页面标题：第二百四十一章 骑士圣殿的灵炉, 内容长度：4140, 段落数：67
#     当前章爬取完成
# 正在爬取第242章：第二百四十二章 凶悍灵炉
#     页面标题：第二百四十二章 凶悍灵炉, 内容长度：4130, 段落数：65
#     当前章爬取完成
# 正在爬取第243章：第二百四十三章 星形灵炉
#     页面标题：第二百四十三章 星形灵炉, 内容长度：4128, 段落数：69
#     当前章爬取完成
# 正在爬取第244章：第二百四十四章 天煞修罗灵炉
#     页面标题：第二百四十四章 天煞修罗灵炉, 内容长度：1983, 段落数：26
#     当前章爬取完成
# 正在爬取第245章：第二百四十五章 废灵炉？
#     页面标题：第二百四十五章 废灵炉？, 内容长度：3828, 段落数：61
#     当前章爬取完成
# 正在爬取第246章：第二百四十六章 固若金汤灵炉
#     页面标题：第二百四十六章 固若金汤灵炉, 内容长度：1967, 段落数：30
#     当前章爬取完成
# 正在爬取第247章：第二百四十七章 守望者，星光！
#     页面标题：第二百四十七章 守望者，星光！, 内容长度：2883, 段落数：40
#     当前章爬取完成
# 正在爬取第248章：第二百四十八章 魔法圣殿考核
#     页面标题：第二百四十八章 魔法圣殿考核, 内容长度：1987, 段落数：26
#     当前章爬取完成
# 正在爬取第249章：第二百四十九章 龙魔法师龙当当
#     页面标题：第二百四十九章 龙魔法师龙当当, 内容长度：1921, 段落数：36
#     当前章爬取完成
# 正在爬取第250章：第二百五十章 龙炎地狱
#     页面标题：第二百五十章 龙炎地狱, 内容长度：1914, 段落数：33
#     当前章爬取完成
# 正在爬取第251章：第二百五十一章 元素圆满
#     页面标题：第二百五十一章 元素圆满, 内容长度：1979, 段落数：27
#     当前章爬取完成
# 正在爬取第252章：第二百五十二章 黑暗觉醒，元素共振
#     页面标题：第二百五十二章 黑暗觉醒，元素共振, 内容长度：2027, 段落数：30
#     当前章爬取完成
# 正在爬取第253章：第二百五十三章 核心灵炉的选择
#     页面标题：第二百五十三章 核心灵炉的选择, 内容长度：4677, 段落数：96
#     当前章爬取完成
# 正在爬取第254章：第二百五十四章 诡异的灵炉
#     页面标题：第二百五十四章 诡异的灵炉, 内容长度：4131, 段落数：59
#     当前章爬取完成
# 正在爬取第255章：第二百五十五章 轻吞慢吐灵炉
#     页面标题：第二百五十五章 轻吞慢吐灵炉, 内容长度：4147, 段落数：53
#     当前章爬取完成
# 正在爬取第256章：第二百五十六章 轻慢的能力
#     页面标题：第二百五十六章 轻慢的能力, 内容长度：1936, 段落数：36
#     当前章爬取完成
# 正在爬取第257章：第二百五十七章 吉阳大营
#     页面标题：第二百五十七章 吉阳大营, 内容长度：4991, 段落数：149
#     当前章爬取完成
# 正在爬取第258章：第二百五十八章 入驻
#     页面标题：第二百五十八章 入驻, 内容长度：2140, 段落数：37
#     当前章爬取完成
# 正在爬取第259章：第二百五十九章 两军对垒
#     页面标题：第二百五十九章 两军对垒, 内容长度：1160, 段落数：13
#     当前章爬取完成
# 正在爬取第260章：第二百六十章 恢宏战场
#     页面标题：第二百六十章 恢宏战场, 内容长度：4726, 段落数：124
#     当前章爬取完成
# 正在爬取第261章：第二百六十一章 炽天使降临
#     页面标题：第二百六十一章 炽天使降临, 内容长度：4514, 段落数：109
#     当前章爬取完成
# 正在爬取第262章：第二百六十二章 出击！
#     页面标题：第二百六十二章 出击！, 内容长度：885, 段落数：16
#     当前章爬取完成
# 正在爬取第263章：第二百六十三章 追踪亡灵的足迹
#     页面标题：第二百六十三章 追踪亡灵的足迹, 内容长度：940, 段落数：20
#     当前章爬取完成
# 正在爬取第264章：第二百六十四章 深蓝色的骷髅头
#     页面标题：第二百六十四章 深蓝色的骷髅头, 内容长度：4102, 段落数：51
#     当前章爬取完成
# 正在爬取第265章：第二百六十五章 恐怖对手
#     页面标题：第二百六十五章 恐怖对手, 内容长度：1092, 段落数：17
#     当前章爬取完成
# 正在爬取第266章：第二百六十六章 九阶亡者
#     页面标题：第二百六十六章 九阶亡者, 内容长度：1231, 段落数：16
#     当前章爬取完成
# 正在爬取第267章：第二百六十七章 逃脱
#     页面标题：第二百六十七章 逃脱, 内容长度：1818, 段落数：33
#     当前章爬取完成
# 正在爬取第268章：第二百六十八章 搏一搏
#     页面标题：第二百六十八章 搏一搏, 内容长度：911, 段落数：17
#     当前章爬取完成
# 正在爬取第269章：第二百六十九章 禁咒，元素狂暴
#     页面标题：第二百六十九章 禁咒，元素狂暴, 内容长度：1253, 段落数：15
#     当前章爬取完成
# 正在爬取第270章：第二百七十章 巨大收获
#     页面标题：第二百七十章 巨大收获, 内容长度：934, 段落数：17
#     当前章爬取完成
# 正在爬取第271章：第二百七十一章 亡灵暴动
#     页面标题：第二百七十一章 亡灵暴动, 内容长度：2130, 段落数：30
#     当前章爬取完成
# 正在爬取第272章：第二百七十二章 他不正常啊！
#     页面标题：第二百七十二章 他不正常啊！, 内容长度：1097, 段落数：16
#     当前章爬取完成
# 正在爬取第273章：第二百七十三章 军方大佬
#     页面标题：第二百七十三章 军方大佬, 内容长度：4117, 段落数：52
#     当前章爬取完成
# 正在爬取第274章：第二百七十四章 同为血契
#     页面标题：第二百七十四章 同为血契, 内容长度：3964, 段落数：44
#     当前章爬取完成
# 正在爬取第275章：第二百七十五章 再见赫本
#     页面标题：第二百七十五章 再见赫本, 内容长度：4174, 段落数：74
#     当前章爬取完成
# 正在爬取第276章：第二百七十六章 你是不是喜欢我
#     页面标题：第二百七十六章 你是不是喜欢我, 内容长度：4244, 段落数：84
#     当前章爬取完成
# 正在爬取第277章：第二百七十七章 全体提升
#     页面标题：第二百七十七章 全体提升, 内容长度：3985, 段落数：56
#     当前章爬取完成
# 正在爬取第278章：第二百七十八章 不一样的龙空空
#     页面标题：第二百七十八章 不一样的龙空空, 内容长度：4212, 段落数：67
#     当前章爬取完成
# 正在爬取第279章：第二百七十九章 深渊之触
#     页面标题：第二百七十九章 深渊之触, 内容长度：4085, 段落数：84
#     当前章爬取完成
# 正在爬取第280章：第二百八十章 大恶魔，都是宝
#     页面标题：第二百八十章 大恶魔，都是宝, 内容长度：4119, 段落数：44
#     当前章爬取完成
# 正在爬取第281章：第二百八十一章 七阶、七阶！
#     页面标题：第二百八十一章 七阶、七阶！, 内容长度：4114, 段落数：56
#     当前章爬取完成
# 正在爬取第282章：第二百八十二章 光明神女
#     页面标题：第二百八十二章 光明神女, 内容长度：4178, 段落数：63
#     当前章爬取完成
# 正在爬取第283章：第二百八十三章 再战魔神
#     页面标题：第二百八十三章 再战魔神, 内容长度：4035, 段落数：57
#     当前章爬取完成
# 正在爬取第284章：第二百八十四章 击杀魔神
#     页面标题：第二百八十四章 击杀魔神, 内容长度：4121, 段落数：63
#     当前章爬取完成
# 正在爬取第285章：第二百八十五章 逆天魔龙一样吸
#     页面标题：第二百八十五章 逆天魔龙一样吸, 内容长度：4121, 段落数：67
#     当前章爬取完成
# 正在爬取第286章：第二百八十六章 阿酒的震惊
#     页面标题：第二百八十六章 阿酒的震惊, 内容长度：4123, 段落数：64
#     当前章爬取完成
# 正在爬取第287章：第二百八十七章 父母失踪
#     页面标题：第二百八十七章 父母失踪, 内容长度：4133, 段落数：77
#     当前章爬取完成
# 正在爬取第288章：第二百八十八章 回家
#     页面标题：第二百八十八章 回家, 内容长度：4135, 段落数：63
#     当前章爬取完成
# 正在爬取第289章：第二百八十九章 亡者剑圣
#     页面标题：第二百八十九章 亡者剑圣, 内容长度：4134, 段落数：67
#     当前章爬取完成
# 正在爬取第290章：第二百九十章 龙当当的表白
#     页面标题：第二百九十章 龙当当的表白, 内容长度：4018, 段落数：69
#     当前章爬取完成
# 正在爬取第291章：第二百九十一章 智慧灵炉的进化之秘
#     页面标题：第二百九十一章 智慧灵炉的进化之秘, 内容长度：4083, 段落数：55
#     当前章爬取完成
# 正在爬取第292章：第二百九十二章 智慧灵炉的考验
#     页面标题：第二百九十二章 智慧灵炉的考验, 内容长度：4015, 段落数：57
#     当前章爬取完成
# 正在爬取第293章：第二百九十三章 觉悟
#     页面标题：第二百九十三章 觉悟, 内容长度：4061, 段落数：87
#     当前章爬取完成
# 正在爬取第294章：第二百九十四章 突然的传送
#     页面标题：第二百九十四章 突然的传送, 内容长度：4058, 段落数：61
#     当前章爬取完成
# 正在爬取第295章：第二百九十五章 刹那红莲
#     页面标题：第二百九十五章 刹那红莲, 内容长度：4140, 段落数：57
#     当前章爬取完成
# 正在爬取第296章：第二百九十六章 碧绿骷髅
#     页面标题：第二百九十六章 碧绿骷髅, 内容长度：4135, 段落数：62
#     当前章爬取完成
# 正在爬取第297章：第二百九十七章 七阶空空
#     页面标题：第二百九十七章 七阶空空, 内容长度：4209, 段落数：56
#     当前章爬取完成
# 正在爬取第298章：第二百九十八章 血脉融合
#     页面标题：第二百九十八章 血脉融合, 内容长度：4091, 段落数：58
#     当前章爬取完成
# 正在爬取第299章：第二百九十九章 我们要挑战
#     页面标题：第二百九十九章 我们要挑战, 内容长度：4111, 段落数：57
#     当前章爬取完成
# 正在爬取第300章：第三百章 挑战，精金基座
#     页面标题：第三百章 挑战，精金基座, 内容长度：4191, 段落数：66
#     当前章爬取完成
# 正在爬取第301章：第三百零一章 裁决与审判
#     页面标题：第三百零一章 裁决与审判, 内容长度：3964, 段落数：52
#     当前章爬取完成
# 正在爬取第302章：第三百零二章 恐怖的鼠大王
#     页面标题：第三百零二章 恐怖的鼠大王, 内容长度：4126, 段落数：55
#     当前章爬取完成
# 正在爬取第303章：第三百零三章 精金基座
#     页面标题：第三百零三章 精金基座, 内容长度：3990, 段落数：62
#     当前章爬取完成
# 正在爬取第304章：第三百零四章 修罗红莲的考验？
#     页面标题：第三百零四章 修罗红莲的考验？, 内容长度：3988, 段落数：56
#     当前章爬取完成
# 正在爬取第305章：第三百零五章 精金基座的传承
#     页面标题：第三百零五章 精金基座的传承, 内容长度：4117, 段落数：68
#     当前章爬取完成
# 正在爬取第306章：第三百零六章 修罗之考，红莲升天
#     页面标题：第三百零六章 修罗之考，红莲升天, 内容长度：4235, 段落数：67
#     当前章爬取完成
# 正在爬取第307章：第三百零七章 当当突破，五头黄金龙
#     页面标题：第三百零七章 当当突破，五头黄金龙, 内容长度：4143, 段落数：77
#     当前章爬取完成
# 正在爬取第308章：第三百零八章 竞拍
#     页面标题：第三百零八章 竞拍, 内容长度：4127, 段落数：62
#     当前章爬取完成
# 正在爬取第309章：第三百零九章 瞒天果
#     页面标题：第三百零九章 瞒天果, 内容长度：4112, 段落数：55
#     当前章爬取完成
# 正在爬取第310章：第三百一十章 闪灵草与圣灵果
#     页面标题：第三百一十章 闪灵草与圣灵果, 内容长度：4194, 段落数：81
#     当前章爬取完成
# 正在爬取第311章：第三百一十一章 智果
#     页面标题：第三百一十一章 智果, 内容长度：4098, 段落数：72
#     当前章爬取完成
# 正在爬取第312章：第三百一十二章 元素精灵
#     页面标题：第三百一十二章 元素精灵, 内容长度：4126, 段落数：80
#     当前章爬取完成
# 正在爬取第313章：第三百一十三章 空间精灵的竞拍
#     页面标题：第三百一十三章 空间精灵的竞拍, 内容长度：4117, 段落数：67
#     当前章爬取完成
# 正在爬取第314章：第三百一十四章 强买强卖？
#     页面标题：第三百一十四章 强买强卖？, 内容长度：4207, 段落数：85
#     当前章爬取完成
# 正在爬取第315章：第三百一十五章 我那么大一个灵炉呢？
#     页面标题：第三百一十五章 我那么大一个灵炉呢？, 内容长度：4155, 段落数：89
#     当前章爬取完成
# 正在爬取第316章：第三百一十六章 火爆天王
#     页面标题：第三百一十六章 火爆天王, 内容长度：4082, 段落数：79
#     当前章爬取完成
# 正在爬取第317章：第三百一十七章 什么？师弟？
#     页面标题：第三百一十七章 什么？师弟？, 内容长度：4075, 段落数：83
#     当前章爬取完成
# 正在爬取第318章：第三百一十八章 遁地神梭和破碎虚空
#     页面标题：第三百一十八章 遁地神梭和破碎虚空, 内容长度：4214, 段落数：80
#     当前章爬取完成
# 正在爬取第319章：第三百一十九章 击败我们
#     页面标题：第三百一十九章 击败我们, 内容长度：4053, 段落数：72
#     当前章爬取完成
# 正在爬取第320章：第三百二十章 赫本失踪
#     页面标题：第三百二十章 赫本失踪, 内容长度：4242, 段落数：68
#     当前章爬取完成
# 正在爬取第321章：第三百二十一章 挑战苟骑士
#     页面标题：第三百二十一章 挑战苟骑士, 内容长度：4192, 段落数：97
#     当前章爬取完成
# 正在爬取第322章：第三百二十二章 莫欺少年穷
#     页面标题：第三百二十二章 莫欺少年穷, 内容长度：4075, 段落数：58
#     当前章爬取完成
# 正在爬取第323章：第三百二十三章 秒杀？
#     页面标题：第三百二十三章 秒杀？, 内容长度：4136, 段落数：79
#     当前章爬取完成
# 正在爬取第324章：第三百二十四章 修炼
#     页面标题：第三百二十四章 修炼, 内容长度：3980, 段落数：73
#     当前章爬取完成
# 正在爬取第325章：第三百二十五章 邪眼暴君
#     页面标题：第三百二十五章 邪眼暴君, 内容长度：4139, 段落数：64
#     当前章爬取完成
# 正在爬取第326章：第三百二十六章 天外奇物
#     页面标题：第三百二十六章 天外奇物, 内容长度：4075, 段落数：67
#     当前章爬取完成
# 正在爬取第327章：第三百二十七章 星光进化
#     页面标题：第三百二十七章 星光进化, 内容长度：4047, 段落数：62
#     当前章爬取完成
# 正在爬取第328章：第三百二十八章 可控血脉，再入圣山
#     页面标题：第三百二十八章 可控血脉，再入圣山, 内容长度：4211, 段落数：65
#     当前章爬取完成
# 正在爬取第329章：第三百二十九章 契约与降临
#     页面标题：第三百二十九章 契约与降临, 内容长度：4178, 段落数：72
#     当前章爬取完成
# 正在爬取第330章：第三百三十章 龙皇的无奈
#     页面标题：第三百三十章 龙皇的无奈, 内容长度：4192, 段落数：72
#     当前章爬取完成
# 正在爬取第331章：第三百三十二章 集体报名
#     页面标题：第三百三十二章 集体报名, 内容长度：4182, 段落数：84
#     当前章爬取完成
# 正在爬取第332章：第三百三十三章 星光璀璨，星力牵引
#     页面标题：第三百三十三章 星光璀璨，星力牵引, 内容长度：3973, 段落数：70
#     当前章爬取完成
# 正在爬取第333章：第三百三十四章 大比开始
#     页面标题：第三百三十四章 大比开始, 内容长度：4209, 段落数：78
#     当前章爬取完成
# 正在爬取第334章：第三百三十五章 首战
#     页面标题：第三百三十五章 首战, 内容长度：3989, 段落数：83
#     当前章爬取完成
# 正在爬取第335章：第三百三十六章 空空抽签
#     页面标题：第三百三十六章 空空抽签, 内容长度：4033, 段落数：75
#     当前章爬取完成
# 正在爬取第336章：第三百三十七章 历史上最年轻的精金基座骑士
#     页面标题：第三百三十七章 历史上最年轻的精金基座骑士, 内容长度：4221, 段落数：107
#     当前章爬取完成
# 正在爬取第337章：第三百三十八章 鼠吞象
#     页面标题：第三百三十八章 鼠吞象, 内容长度：4067, 段落数：93
#     当前章爬取完成
# 正在爬取第338章：第三百三十九章 刹那永恒的魔法
#     页面标题：第三百三十九章 刹那永恒的魔法, 内容长度：2220, 段落数：44
#     当前章爬取完成
# 正在爬取第339章：第三百四十章 日月同辉
#     页面标题：第三百四十章 日月同辉, 内容长度：3947, 段落数：88
#     当前章爬取完成
# 正在爬取第340章：第三百四十一章 冰雷之罚与火神降临
#     页面标题：第三百四十一章 冰雷之罚与火神降临, 内容长度：3813, 段落数：80
#     当前章爬取完成
# 正在爬取第341章：第三百四十二章 桃林林的彷徨
#     页面标题：第三百四十二章 桃林林的彷徨, 内容长度：4169, 段落数：92
#     当前章爬取完成
# 正在爬取第342章：第三百四十四章 黄金镇魔树
#     页面标题：第三百四十四章 黄金镇魔树, 内容长度：4068, 段落数：94
#     当前章爬取完成
# 正在爬取第343章：第三百四十五章 桃林林胜
#     页面标题：第三百四十五章 桃林林胜, 内容长度：4168, 段落数：93
#     当前章爬取完成
# 正在爬取第344章：第三百四十六章 同位共振龙语吟唱
#     页面标题：第三百四十六章 同位共振龙语吟唱, 内容长度：4266, 段落数：101
#     当前章爬取完成
# 正在爬取第345章：第三百四十七章 全体晋级
#     页面标题：第三百四十七章 全体晋级, 内容长度：4146, 段落数：105
#     当前章爬取完成
# 正在爬取第346章：第三百四十八章 对阵，子桑琉荧
#     页面标题：第三百四十八章 对阵，子桑琉荧, 内容长度：4194, 段落数：109
#     当前章爬取完成
# 正在爬取第347章：第三百四十九章 我为神体
#     页面标题：第三百四十九章 我为神体, 内容长度：4193, 段落数：108
#     当前章爬取完成
# 正在爬取第348章：第三百五十章 这是什么龙?
#     页面标题：第三百五十章 这是什么龙?, 内容长度：3796, 段落数：94
#     当前章爬取完成
# 正在爬取第349章：第三百五十一章 神器？
#     页面标题：第三百五十一章 神器？, 内容长度：4209, 段落数：76
#     当前章爬取完成
# 正在爬取第350章：第三百五十二章 当当晋级
#     页面标题：第三百五十二章 当当晋级, 内容长度：4231, 段落数：90
#     当前章爬取完成
# 正在爬取第351章：第三百五十三章 纵论神器
#     页面标题：第三百五十三章 纵论神器, 内容长度：4096, 段落数：79
#     当前章爬取完成
# 正在爬取第352章：第三百五十四章 决赛开始
#     页面标题：第三百五十四章 决赛开始, 内容长度：4252, 段落数：89
#     当前章爬取完成
# 正在爬取第353章：第三百五十五章 抽签分组
#     页面标题：第三百五十五章 抽签分组, 内容长度：4372, 段落数：125
#     当前章爬取完成
# 正在爬取第354章：第三百五十六章 雷场
#     页面标题：第三百五十六章 雷场, 内容长度：4088, 段落数：114
#     当前章爬取完成
# 正在爬取第355章：第三百五十七章 三领域带来的绝望
#     页面标题：第三百五十七章 三领域带来的绝望, 内容长度：4107, 段落数：114
#     当前章爬取完成
# 正在爬取第356章：第358章 首胜
#     页面标题：第358章 首胜, 内容长度：3931, 段落数：114
#     当前章爬取完成
# 正在爬取第357章：神印王座2皓月当空 第359章 龙当当出战
#     页面标题：神印王座2皓月当空 第359章 龙当当出战, 内容长度：3940, 段落数：108
#     当前章爬取完成
# 正在爬取第358章：第三百六十章 雄霸天下汪常欣
#     页面标题：第三百六十章 雄霸天下汪常欣, 内容长度：3191, 段落数：72
#     当前章爬取完成
# 正在爬取第359章：第三百六十一章 雄霸天下
#     页面标题：第三百六十一章 雄霸天下, 内容长度：4316, 段落数：114
#     当前章爬取完成
# 正在爬取第360章：第三百六十二章 唐雷光心中的凌梦露
#     页面标题：第三百六十二章 唐雷光心中的凌梦露, 内容长度：4228, 段落数：107
#     当前章爬取完成
# 正在爬取第361章：第三百六十三章 她的极限在哪里？
#     页面标题：第三百六十三章 她的极限在哪里？, 内容长度：4297, 段落数：109
#     当前章爬取完成
# 正在爬取第362章：第三百六十四章 黄金龙骑士
#     页面标题：第三百六十四章 黄金龙骑士, 内容长度：4161, 段落数：96
#     当前章爬取完成
# 正在爬取第363章：第三百六十五章 子桑琉荧的强大
#     页面标题：第三百六十五章 子桑琉荧的强大, 内容长度：4213, 段落数：111
#     当前章爬取完成
# 正在爬取第364章：第三百六十六章 戒律牧师
#     页面标题：第三百六十六章 戒律牧师, 内容长度：4208, 段落数：102
#     当前章爬取完成
# 正在爬取第365章：第367章 双修守护与惩戒？
#     页面标题：第367章 双修守护与惩戒？, 内容长度：4238, 段落数：118
#     当前章爬取完成
# 正在爬取第366章：第三百六十八章 龙空空VS时泽宇
#     页面标题：第三百六十八章 龙空空VS时泽宇, 内容长度：4247, 段落数：107
#     当前章爬取完成
# 正在爬取第367章：第369章 狂暴鼠大王
#     页面标题：第369章 狂暴鼠大王, 内容长度：4251, 段落数：97
#     当前章爬取完成
# 正在爬取第368章：第三百七十章 太阳圣决与盾击冲锋
#     页面标题：第三百七十章 太阳圣决与盾击冲锋, 内容长度：4267, 段落数：132
#     当前章爬取完成
# 正在爬取第369章：第三百七十一章 父子
#     页面标题：第三百七十一章 父子, 内容长度：4217, 段落数：105
#     当前章爬取完成
# 正在爬取第370章：第三百七十二章 准备硬刚的空空
#     页面标题：第三百七十二章 准备硬刚的空空, 内容长度：4088, 段落数：93
#     当前章爬取完成
# 正在爬取第371章：第三百七十三章 龙空空VS子桑琉荧
#     页面标题：第三百七十三章 龙空空VS子桑琉荧, 内容长度：4164, 段落数：106
#     当前章爬取完成
# 正在爬取第372章：第三百七十四章 禁咒，元素审判
#     页面标题：第三百七十四章 禁咒，元素审判, 内容长度：4087, 段落数：92
#     当前章爬取完成
# 正在爬取第373章：第三百七十五章 平局？
#     页面标题：第三百七十五章 平局？, 内容长度：4220, 段落数：110
#     当前章爬取完成
# 正在爬取第374章：第三百七十六章 八强
#     页面标题：第三百七十六章 八强, 内容长度：4277, 段落数：110
#     当前章爬取完成
# 正在爬取第375章：第三百七十七章 八强分组
#     页面标题：第三百七十七章 八强分组, 内容长度：4196, 段落数：92
#     当前章爬取完成
# 正在爬取第376章：第三百七十八章 六道轮回
#     页面标题：第三百七十八章 六道轮回, 内容长度：4621, 段落数：87
#     当前章爬取完成
# 正在爬取第377章：第三百七十九章 凌梦露的底牌
#     页面标题：第三百七十九章 凌梦露的底牌, 内容长度：4258, 段落数：131
#     当前章爬取完成

# %%
txtfp.close()
